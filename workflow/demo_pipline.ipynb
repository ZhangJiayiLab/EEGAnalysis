# %%
import EEGAnalysis as ea
# import h5py
# import numpy as np

# %% [markdown]
# ## Create Dataset and New Patient Folders

# %%
_data_dir = './Data'  ## set data folder
ea_manager = ea.DataManager(_data_dir)  ## create data manager
patient_1 = ea_manager.create_patient('P_1')  ## create new patient

# %% [markdown]
# ### import new raw data

# %%
_append_raw_dir = '/Users/yizhan/Desktop/ZhangLab/Observer/Data/Chen Zhou/EEG/Raw'
patient_1 = ea_manager.update_raw_to_patient('P_1', _append_raw_dir, copy=False, overwrite=False)
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 37462.01it/s]

# %% [markdown]
# ### create isplit format data

# %%
patient_1 = ea_manager.create_isplit('P_1', 4)
# Out:
# 100%|██████████| 2583/2583 [03:00<00:00, 13.82it/s]

# %% [markdown]
# ### check and update marker and mbias

# %%
if patient_1.check_marker():
    print('markers all set')
# Out:
# all set.
# markers all set

# %%
patient_1.update_marker(name='180910-1', marker_array=[1,3,7,8], paradigm='1-5')
# Out:
# marker alread in record: 180910-1; use `overwrite` flag to overwrite.

# %%
patient_1.update_mbias()
# Out:
# mbias alread in record: 180829-3; use `overwrite` flag to overwrite.
# 180831-1-1-10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     856             try:
# --> 857                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     858             except Exception:
#
# ~/miniconda/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/miniconda/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/miniconda/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3615a9958c28> in <module>
# ----> 1 patient_1.update_mbias()
#
# ~/Desktop/ZhangLab/Observer/EEGAnalysis/workflow/EEGAnalysis/datamanager.py in update_mbias(self, name, mbias, paradigm, overwrite, n)
#     181                     _idx = random.randrange(len(self._sgch_config.keys()))
#     182                     self._mbias_preview(_idx, each, _each_paradigm)
# --> 183                     _input = input('type mbias, or \'.\' to skip this channel:')
#     184                     if _input == '.':
#     185                         pass
#
# ~/miniconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     830             self._parent_ident,
#     831             self._parent_header,
# --> 832             password=False,
#     833         )
#     834
#
# ~/miniconda/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     860             except KeyboardInterrupt:
#     861                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 862                 raise KeyboardInterrupt
#     863             else:
#     864                 break
#
# KeyboardInterrupt:
# type mbias, or '.' to skip this channel:1.1
